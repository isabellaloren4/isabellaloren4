# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellaloren4/isabellaloren4/blob/main/ml_evaluation_acp_new_acp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pytoda
# !pip install catboost
# !pip install scikit-optimize
# !pip install xgboost
# !pip install lightgbm
# !pip install openpyxl
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: pytoda in /opt/conda/lib/python3.10/site-packages (1.1.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pytoda) (1.23.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from pytoda) (1.3.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from pytoda) (2.0.3)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from pytoda) (2.0.1)
# Requirement already satisfied: diskcache in /opt/conda/lib/python3.10/site-packages (from pytoda) (5.6.3)
# Requirement already satisfied: dill>=0.3.3 in /opt/conda/lib/python3.10/site-packages (from pytoda) (0.3.7)
# Requirement already satisfied: selfies>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from pytoda) (2.1.1)
# Requirement already satisfied: upfp in /opt/conda/lib/python3.10/site-packages (from pytoda) (0.0.5)
# Requirement already satisfied: SmilesPE>=0.0.3 in /opt/conda/lib/python3.10/site-packages (from pytoda) (0.0.3)
# Requirement already satisfied: pyfaidx in /opt/conda/lib/python3.10/site-packages (from pytoda) (0.7.2.1)
# Requirement already satisfied: pubchempy in /opt/conda/lib/python3.10/site-packages (from pytoda) (1.0.4)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from pytoda) (6.0.1)
# Requirement already satisfied: Unidecode in /opt/conda/lib/python3.10/site-packages (from pytoda) (1.3.6)
# Requirement already satisfied: rdkit-pypi>=2021.9.3 in /opt/conda/lib/python3.10/site-packages (from pytoda) (2022.9.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi>=2021.9.3->pytoda) (10.0.0)
# Requirement already satisfied: fastprogress in /opt/conda/lib/python3.10/site-packages (from SmilesPE>=0.0.3->pytoda) (1.0.3)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from SmilesPE>=0.0.3->pytoda) (4.3.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (2.8.8)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->pytoda) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->pytoda) (68.0.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->pytoda) (0.41.1)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.4.0->pytoda) (3.27.2)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.4.0->pytoda) (16.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->pytoda) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pytoda) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pytoda) (2023.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from pyfaidx->pytoda) (1.16.0)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->pytoda) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->pytoda) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->pytoda) (3.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->SmilesPE>=0.0.3->pytoda) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->pytoda) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->pytoda) (1.3.0)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.10/site-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost) (1.11.1)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: scikit-optimize in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize) (1.3.1)
# Requirement already satisfied: pyaml>=16.9 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize) (23.9.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize) (1.3.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (1.7.6)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.11.1)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.11.1)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
from numpy import mean
from numpy import std
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis, LinearDiscriminantAnalysis
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import *
from threading import Thread
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.base import BaseEstimator, ClassifierMixin
from csv import writer

from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import as_completed

# %%
def experiment(data_name, model_name, model, params, X_train, y_train, X_test, y_test, i):

    # configure the cross-validation procedure
    cv_inner = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)
    # define search
    search = BayesSearchCV(model, params, scoring='accuracy', cv=cv_inner, n_iter=10, refit=True, random_state=1, n_jobs=1)

    # execute search
    result = search.fit(X_train, y_train)

    # get the best performing model fit on the whole training set
    best_model = result.best_estimator_

    # evaluate model on the hold out dataset
    yhat = best_model.predict(X_test)

    # evaluate the model
    acc = accuracy_score(y_test, yhat)
    prec = precision_score(y_test, yhat)
    rec = recall_score(y_test, yhat)
    f1 = f1_score(y_test, yhat)
    mcc = matthews_corrcoef(y_test, yhat)

    # store the result
    #results.append([data_name, model_name, i, acc, rec, prec, f1, mcc, result.best_score_, result.best_params_])
    results = [data_name, model_name, i, acc, rec, prec, f1, mcc, result.best_score_, result.best_params_]
    with open('results/'+data_name+'_results.csv', 'a') as f_object:
        writer_object = writer(f_object)
        writer_object.writerow(results)
        f_object.close()

    # report progress
    print(f"{data_name}, {model_name} {i} > acc={acc:.2f}, est={result.best_score_:.2f}, cfg={result.best_params_}")

# %%
# definição dos modelos e parametros
model_params = {
          'lr': {'model': LogisticRegression(),
                'params': {
                          'C': Real(1e-4, 1e4, prior='log-uniform'),
                          'fit_intercept': Categorical([True, False]),
                          'solver': Categorical(['newton-cg', 'liblinear', 'sag', 'saga'])}},

          'knn': {'model': KNeighborsClassifier(),
                  'params': {
                            'n_neighbors': Integer(1, 50),
                            'weights': Categorical(['uniform', 'distance']),
                            'algorithm': Categorical(['auto', 'ball_tree', 'kd_tree', 'brute']),
                            'p': Integer(1, 5)}},

          'nb': {'model': GaussianNB(),
                'params': {
                          'var_smoothing': Real(1e-10, 1e-1, prior='log-uniform')}},

          'dt': {'model': DecisionTreeClassifier(),
                'params': {
                          'criterion': Categorical(['gini', 'entropy']),
                          'splitter': Categorical(['best', 'random']),
                          'max_depth': Integer(3, 30),
                          'min_samples_split': Integer(2, 10),
                          'min_samples_leaf': Integer(1, 10),
                          'max_features': Real(0.1, 1.0, prior='uniform')}},

          'svm': {'model': LinearSVC(),
                  'params': {
                            'C': Real(1e-6, 1e+6, prior='log-uniform'),
                            'loss': Categorical(['hinge', 'squared_hinge']),
                            'tol': Real(1e-6, 1e-2, prior='log-uniform')}},

          'gpc': {'model': GaussianProcessClassifier(),
                  'params': {
                            'optimizer': Categorical(['fmin_l_bfgs_b', None]),
                            'n_restarts_optimizer': Integer(0, 10),
                            'max_iter_predict': Integer(100, 1000)}},

          'mlp': {'model': MLPClassifier(),
                  'params': {
                            'hidden_layer_sizes': Integer(10,100),
                            'activation': Categorical(['identity', 'logistic', 'tanh', 'relu']),
                            'solver': Categorical(['sgd', 'adam']),
                            'alpha': Real(1e-5, 1e-1, prior='log-uniform'),
                            'learning_rate': Categorical(['constant', 'invscaling', 'adaptive']),
                            'learning_rate_init': Real(1e-4, 1e-1, prior='log-uniform'),
                            'max_iter': Integer(1000,1001)}},

          'ridge': {'model': RidgeClassifier(),
                    'params': {
                              'alpha': Real(1e-4, 1e4, prior='log-uniform'),
                              'fit_intercept': Categorical([True, False]),
                              'solver': Categorical(['auto', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'])}},

          'rf': {'model': RandomForestClassifier(),
                'params': {
                          'n_estimators': Integer(10, 500),
                          'criterion': Categorical(['gini', 'entropy']),
                          'max_depth': Integer(3, 30),
                          'min_samples_split': Integer(2, 10),
                          'min_samples_leaf': Integer(1, 10),
                          'max_features': Real(0.1, 1.0, prior='uniform'),
                          'bootstrap': Categorical([True, False]),
                          'class_weight': Categorical(['balanced', 'balanced_subsample', None])}},

          'qda': {'model': QuadraticDiscriminantAnalysis(),
                  'params': {
                            'reg_param': Real(0, 1, prior='uniform'),
                            'store_covariance': Categorical([True, False]),
                            'tol': Real(1e-5, 1e-1, prior='log-uniform')}},

          'ada': {'model': AdaBoostClassifier(),
                  'params': {
                            'n_estimators': Integer(10, 500),
                            'learning_rate': Real(1e-3, 1, prior='log-uniform'),
                            'algorithm': Categorical(['SAMME', 'SAMME.R'])}},

          'gbc': {'model': GradientBoostingClassifier(),
                  'params': {
                            'n_estimators': Integer(10, 500),
                            'learning_rate': Real(1e-3, 1, prior='log-uniform'),
                            'max_depth': Integer(3, 10),
                            'min_samples_split': Integer(2, 10),
                            'min_samples_leaf': Integer(1, 10),
                            'max_features': Real(0.1, 1.0, prior='uniform'),
                            'subsample': Real(0.1, 1.0, prior='uniform')}},

          'lda': {'model': LinearDiscriminantAnalysis(),
                  'params': {
                            'solver': Categorical(['lsqr', 'eigen']),
                            'shrinkage': Real(0, 1, prior='uniform'),
                            'tol': Real(1e-6, 1e-4, prior='log-uniform')}},

          'et': {'model': ExtraTreesClassifier(),
                'params': {
                          'n_estimators': Integer(10, 500),
                          'criterion': Categorical(['gini', 'entropy']),
                          'max_depth': Integer(3, 30),
                          'min_samples_split': Integer(2, 10),
                          'min_samples_leaf': Integer(1, 10),
                          'max_features': Real(0.1, 1.0, prior='uniform'),
                          'bootstrap': Categorical([True, False]),
                          'class_weight': Categorical(['balanced', 'balanced_subsample', None])}},

          'xgboost': {'model': XGBClassifier(),
                      'params': {
                                'learning_rate': Real(0.01, 0.3, prior='uniform'),
                                'n_estimators': Integer(50, 500),
                                'max_depth': Integer(3, 10),
                                'min_child_weight': Integer(1, 10),
                                'gamma': Real(0, 1, prior='uniform'),
                                'subsample': Real(0.5, 1, prior='uniform'),
                                'colsample_bytree': Real(0.5, 1, prior='uniform'),
                                'reg_alpha': Real(0, 1, prior='uniform'),
                                'reg_lambda': Real(1, 3, prior='uniform'),
                                'scale_pos_weight': Real(1, 5, prior='uniform')}},

          'lightgbm': {'model': LGBMClassifier(verbose=-1),
                     'params': {
                                'learning_rate': Real(1e-3, 1, prior='log-uniform'),
                                'n_estimators': Integer(10, 500),
                                'num_leaves': Integer(2, 100),
                                'max_depth': Integer(3, 10),
                                'min_child_samples': Integer(1, 50),
                                'min_child_weight': Real(1e-5, 1e-3, prior='log-uniform'),
                                'subsample': Real(0.1, 1.0, prior='uniform'),
                                'colsample_bytree': Real(0.1, 1.0, prior='uniform'),
                                'reg_alpha': Real(0, 1, prior='uniform'),
                                'reg_lambda': Real(0, 1, prior='uniform')}},

          'catboost': {'model': CatBoostClassifier(verbose=0),
                      'params': {
                                'learning_rate': Real(1e-3, 1, prior='log-uniform'),
                                'iterations': Integer(10, 500),
                                'depth': Integer(3, 10),
                                'l2_leaf_reg': Real(1, 10, prior='uniform'),
                                'border_count': Integer(1, 255),
                                'bagging_temperature': Real(0, 1, prior='uniform'),
                                'random_strength': Real(1e-9, 10, prior='log-uniform')}}
}

# %%
# definição dos modelos e parametros
#model_params = {
          #'mlp': {'model': MLPClassifier(),
                  #'params': {
                            #'hidden_layer_sizes': Integer(10,100),
                            #'activation': Categorical(['identity', 'logistic', 'tanh', 'relu']),
                            #'solver': Categorical(['sgd', 'adam']),
                            #'alpha': Real(1e-5, 1e-1, prior='log-uniform'),
                            #'learning_rate': Categorical(['constant', 'invscaling', 'adaptive']),
                            #'learning_rate_init': Real(1e-4, 1e-1, prior='log-uniform'),
                            #'max_iter': Integer(1000,1001)}}
#}

# %%
facp = open("acp.txt",'r')
fnacp = open("nacp.txt", 'r')

acp = facp.readlines()
nacp = fnacp.readlines()

facp.close()
fnacp.close()

X = []
y = []
for i in range(len(acp)):
    X.append(acp[i][:-1])
    y.append(1)

for i in range(len(nacp)):
    X.append(nacp[i][:-1])
    y.append(0)

X = np.array(X)
y = np.array(y)

# %%
# T é um lista dos dados transformados que serão utilizados nos experimentos
T = []

#carregar dos arquivos os dados transformados:

#---1D DeepChem
#T.append( ('maccskeys', pd.read_csv('features/maccskeys.csv', header=None).to_numpy()) )
#T.append( ('circular', pd.read_csv('features/circular.csv', header=None).to_numpy()) )
#T.append( ('mol2vec', pd.read_csv('features/mol2vec.csv', header=None).to_numpy()) )
#T.append( ('rdkit', pd.read_csv('features/rdkit.csv', header=None).to_numpy()) )
#T.append( ('bpsymmetry', pd.read_csv('features/bpsymmetry.csv', header=None).to_numpy()) )
T.append( ('modlamp', pd.read_csv('features/modlamp.csv', header=None).to_numpy()) )
T.append( ('fastatoseq', pd.read_csv('features/fastatoseq.csv', header=None).to_numpy()) )
T.append( ('smilestoseq', pd.read_csv('features/smilestoseq.csv', header=None).to_numpy()) )
#T.append( ('mordred', normalize(pd.read_csv('features/mordred.csv', header=None).to_numpy())) )

#---1D protPy
#T.append( ('AAC', pd.read_csv('features/AAC.csv', header=None).to_numpy()) )
#T.append( ('PAAC', pd.read_csv('features/PAAC.csv', header=None).to_numpy()) )
#T.append( ('APAAC', pd.read_csv('features/APAAC.csv', header=None).to_numpy()) )
#T.append( ('CTD', pd.read_csv('features/CTD.csv', header=None).to_numpy()) )
#T.append( ('CTriad', pd.read_csv('features/CTriad.csv', header=None).to_numpy()) )
#T.append( ('DPC', pd.read_csv('features/DPC.csv', header=None).to_numpy()) )
#T.append( ('TPC', pd.read_csv('features/TPC.csv', header=None).to_numpy()) )


#---2D DeepChem
#T.append( ('coulombmatrix', pd.read_csv('features/coulombmatrix.csv', low_memory=False, header=None).to_numpy()) )
#T.append( ('onehot', pd.read_csv('features/onehot.csv', low_memory=False, header=None).to_numpy()) )
#T.append( ('smiles2image', pd.read_csv('features/smiles2image.csv', low_memory=False, header=None).to_numpy()) )

# %%
import time

# configure the cross-validation procedure
cv_outer = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=1)

#lista para armazenar a referencia das threads
threads = []

# create a thread pool with max worker threads
pool = ThreadPoolExecutor(max_workers=8)

for data_name, X_ in T:

    for i, (train_ix, test_ix) in enumerate(cv_outer.split(X_, y)):

        # split data
        X_train, X_test = X_[train_ix, :], X_[test_ix, :]
        y_train, y_test = y[train_ix], y[test_ix]

        for model_name, mp in model_params.items():

            # adiciona experimento na lista de threads: pool
            exp = pool.submit(experiment, data_name, model_name, mp['model'],mp['params'], X_train, y_train, X_test, y_test, i) # does not block

            #adiciona na lista para salvar a referencia da thread
            threads.append(exp)

            time.sleep(0.1)

# aguarda pela finalização das threads
for exp in as_completed(threads):
    exp.result()
# Out:
# modlamp, nb 0 > acc=0.64, est=0.65, cfg=OrderedDict([('var_smoothing', 0.0029757134630289256)])
# modlamp, lr 0 > acc=0.64, est=0.66, cfg=OrderedDict([('C', 5502.07329435664), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, dt 0 > acc=0.62, est=0.65, cfg=OrderedDict([('criterion', 'gini'), ('max_depth', 15), ('max_features', 0.6380599656985619), ('min_samples_leaf', 3), ('min_samples_split', 7), ('splitter', 'best')])
# modlamp, qda 0 > acc=0.65, est=0.66, cfg=OrderedDict([('reg_param', 0.31614545298544944), ('store_covariance', True), ('tol', 0.019958994474678478)])
# modlamp, svm 0 > acc=0.63, est=0.66, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, knn 0 > acc=0.67, est=0.68, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 17), ('p', 1), ('weights', 'distance')])
# modlamp, ridge 0 > acc=0.64, est=0.67, cfg=OrderedDict([('alpha', 41.79842712265741), ('fit_intercept', False), ('solver', 'lsqr')])
# modlamp, lda 0 > acc=0.64, est=0.66, cfg=OrderedDict([('shrinkage', 0.8303990122072878), ('solver', 'eigen'), ('tol', 3.465259624840768e-05)])
# modlamp, gpc 0 > acc=0.65, est=0.66, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, xgboost 0 > acc=0.67, est=0.69, cfg=OrderedDict([('colsample_bytree', 0.8517200209274532), ('gamma', 0.4115729954640338), ('learning_rate', 0.04506633355900484), ('max_depth', 6), ('min_child_weight', 5), ('n_estimators', 443), ('reg_alpha', 0.99234917935201), ('reg_lambda', 2.2577393150266474), ('scale_pos_weight', 3.108626196745969), ('subsample', 0.823873025266173)])
# modlamp, lr 1 > acc=0.66, est=0.65, cfg=OrderedDict([('C', 0.0008547165193950983), ('fit_intercept', True), ('solver', 'sag')])
# modlamp, knn 1 > acc=0.68, est=0.67, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 21), ('p', 1), ('weights', 'distance')])
# modlamp, nb 1 > acc=0.64, est=0.65, cfg=OrderedDict([('var_smoothing', 7.038195949977948e-05)])
# modlamp, dt 1 > acc=0.63, est=0.64, cfg=OrderedDict([('criterion', 'gini'), ('max_depth', 15), ('max_features', 0.6380599656985619), ('min_samples_leaf', 3), ('min_samples_split', 7), ('splitter', 'best')])
# modlamp, svm 1 > acc=0.66, est=0.64, cfg=OrderedDict([('C', 2.498809490289807e-05), ('loss', 'squared_hinge'), ('tol', 0.00031838927761288757)])
# modlamp, et 0 > acc=0.67, est=0.70, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 8), ('max_features', 0.6647325698298886), ('min_samples_leaf', 1), ('min_samples_split', 7), ('n_estimators', 160)])
# modlamp, gpc 1 > acc=0.65, est=0.61, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, lightgbm 0 > acc=0.69, est=0.70, cfg=OrderedDict([('colsample_bytree', 0.7330960376694159), ('learning_rate', 0.01716797160783964), ('max_depth', 4), ('min_child_samples', 21), ('min_child_weight', 6.832822098683475e-05), ('n_estimators', 438), ('num_leaves', 99), ('reg_alpha', 0.6288696575133238), ('reg_lambda', 0.5271565491864922), ('subsample', 0.6829714454791113)])
# modlamp, mlp 0 > acc=0.65, est=0.69, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.001186334067387707), ('hidden_layer_sizes', 88), ('learning_rate', 'constant'), ('learning_rate_init', 0.0018322104829247405), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, ridge 1 > acc=0.66, est=0.65, cfg=OrderedDict([('alpha', 5502.07329435664), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, qda 1 > acc=0.65, est=0.65, cfg=OrderedDict([('reg_param', 0.8303990122072878), ('store_covariance', False), ('tol', 0.012008024267551608)])
# modlamp, gbc 0 > acc=0.70, est=0.70, cfg=OrderedDict([('learning_rate', 0.08895160416425743), ('max_depth', 4), ('max_features', 0.6416120797822377), ('min_samples_leaf', 4), ('min_samples_split', 4), ('n_estimators', 410), ('subsample', 0.6061311836728094)])
# modlamp, lda 1 > acc=0.65, est=0.65, cfg=OrderedDict([('shrinkage', 0.11647776222456444), ('solver', 'lsqr'), ('tol', 1.7843465964125007e-05)])
# modlamp, ada 0 > acc=0.64, est=0.66, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.019695923033569554), ('n_estimators', 303)])
# modlamp, catboost 0 > acc=0.70, est=0.70, cfg=OrderedDict([('bagging_temperature', 0.4474239528275963), ('border_count', 133), ('depth', 9), ('iterations', 343), ('l2_leaf_reg', 4.788926090837039), ('learning_rate', 0.026043451730689893), ('random_strength', 2.1895652968697026e-06)])
# modlamp, mlp 1 > acc=0.67, est=0.68, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.001186334067387707), ('hidden_layer_sizes', 88), ('learning_rate', 'constant'), ('learning_rate_init', 0.0018322104829247405), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, lightgbm 1 > acc=0.71, est=0.67, cfg=OrderedDict([('colsample_bytree', 0.38453090768690446), ('learning_rate', 0.16467900766362875), ('max_depth', 9), ('min_child_samples', 28), ('min_child_weight', 0.00018721863266560728), ('n_estimators', 28), ('num_leaves', 50), ('reg_alpha', 0.005512267694319562), ('reg_lambda', 0.13150457755909709), ('subsample', 0.6167528732376905)])
# modlamp, lr 2 > acc=0.65, est=0.64, cfg=OrderedDict([('C', 439.73607701862176), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, knn 2 > acc=0.66, est=0.65, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 4), ('p', 3), ('weights', 'distance')])
# modlamp, nb 2 > acc=0.64, est=0.64, cfg=OrderedDict([('var_smoothing', 0.00014191129358860486)])
# modlamp, dt 2 > acc=0.64, est=0.65, cfg=OrderedDict([('criterion', 'entropy'), ('max_depth', 21), ('max_features', 0.6631656475573788), ('min_samples_leaf', 8), ('min_samples_split', 9), ('splitter', 'best')])
# modlamp, svm 2 > acc=0.66, est=0.64, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, xgboost 1 > acc=0.70, est=0.66, cfg=OrderedDict([('colsample_bytree', 0.8513224962221795), ('gamma', 0.061651731814223246), ('learning_rate', 0.11929864409041845), ('max_depth', 4), ('min_child_weight', 5), ('n_estimators', 450), ('reg_alpha', 0.05848718590845105), ('reg_lambda', 1.5113896356547571), ('scale_pos_weight', 2.9158263103973225), ('subsample', 0.8380437488771677)])
# modlamp, rf 0 > acc=0.69, est=0.71, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced'), ('criterion', 'gini'), ('max_depth', 11), ('max_features', 0.5031571727059295), ('min_samples_leaf', 7), ('min_samples_split', 7), ('n_estimators', 183)])
# modlamp, gpc 2 > acc=0.67, est=0.63, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, ridge 2 > acc=0.66, est=0.65, cfg=OrderedDict([('alpha', 42.415084333227796), ('fit_intercept', False), ('solver', 'cholesky')])
# modlamp, qda 2 > acc=0.65, est=0.66, cfg=OrderedDict([('reg_param', 0.11647776222456444), ('store_covariance', True), ('tol', 0.0031838927761288754)])
# modlamp, et 1 > acc=0.72, est=0.70, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 21), ('max_features', 0.478892609083704), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 458)])
# modlamp, gbc 1 > acc=0.71, est=0.68, cfg=OrderedDict([('learning_rate', 0.021992361138544005), ('max_depth', 7), ('max_features', 0.8796230877866216), ('min_samples_leaf', 7), ('min_samples_split', 5), ('n_estimators', 241), ('subsample', 0.40063221110643055)])
# modlamp, lda 2 > acc=0.66, est=0.64, cfg=OrderedDict([('shrinkage', 0.6835574398742915), ('solver', 'eigen'), ('tol', 1.1450451548138902e-06)])
# modlamp, ada 1 > acc=0.67, est=0.64, cfg=OrderedDict([('algorithm', 'SAMME'), ('learning_rate', 0.10477964498145864), ('n_estimators', 317)])
# modlamp, mlp 2 > acc=0.69, est=0.67, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.001186334067387707), ('hidden_layer_sizes', 88), ('learning_rate', 'constant'), ('learning_rate_init', 0.0018322104829247405), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, catboost 1 > acc=0.71, est=0.68, cfg=OrderedDict([('bagging_temperature', 0.6497179282036988), ('border_count', 26), ('depth', 7), ('iterations', 196), ('l2_leaf_reg', 2.9772252632518375), ('learning_rate', 0.2817502752184049), ('random_strength', 0.0004204165641133956)])
# modlamp, xgboost 2 > acc=0.70, est=0.68, cfg=OrderedDict([('colsample_bytree', 0.8517200209274532), ('gamma', 0.4115729954640338), ('learning_rate', 0.04506633355900484), ('max_depth', 6), ('min_child_weight', 5), ('n_estimators', 443), ('reg_alpha', 0.99234917935201), ('reg_lambda', 2.2577393150266474), ('scale_pos_weight', 3.108626196745969), ('subsample', 0.823873025266173)])
# modlamp, lr 3 > acc=0.63, est=0.67, cfg=OrderedDict([('C', 439.73607701862176), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, knn 3 > acc=0.68, est=0.70, cfg=OrderedDict([('algorithm', 'kd_tree'), ('n_neighbors', 22), ('p', 3), ('weights', 'distance')])
# modlamp, nb 3 > acc=0.64, est=0.66, cfg=OrderedDict([('var_smoothing', 0.0029757134630289256)])
# modlamp, lightgbm 2 > acc=0.70, est=0.69, cfg=OrderedDict([('colsample_bytree', 0.5026815575448367), ('learning_rate', 0.03594638748649799), ('max_depth', 9), ('min_child_samples', 34), ('min_child_weight', 6.94998033480578e-05), ('n_estimators', 241), ('num_leaves', 35), ('reg_alpha', 0.9136997933552291), ('reg_lambda', 0.33305400272462654), ('subsample', 0.4139431437688128)])
# modlamp, dt 3 > acc=0.62, est=0.68, cfg=OrderedDict([('criterion', 'gini'), ('max_depth', 15), ('max_features', 0.6380599656985619), ('min_samples_leaf', 3), ('min_samples_split', 7), ('splitter', 'best')])
# modlamp, rf 1 > acc=0.69, est=0.67, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced'), ('criterion', 'entropy'), ('max_depth', 7), ('max_features', 0.5438579263598313), ('min_samples_leaf', 9), ('min_samples_split', 2), ('n_estimators', 135)])
# modlamp, svm 3 > acc=0.64, est=0.67, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, ridge 3 > acc=0.63, est=0.67, cfg=OrderedDict([('alpha', 1050.705620369744), ('fit_intercept', False), ('solver', 'auto')])
# modlamp, gpc 3 > acc=0.64, est=0.65, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 3 > acc=0.64, est=0.67, cfg=OrderedDict([('reg_param', 0.6835574398742915), ('store_covariance', False), ('tol', 1.311128406562766e-05)])
# modlamp, et 2 > acc=0.71, est=0.70, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 23), ('max_features', 0.8721933994149386), ('min_samples_leaf', 4), ('min_samples_split', 8), ('n_estimators', 460)])
# modlamp, ada 2 > acc=0.67, est=0.65, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.01716797160783964), ('n_estimators', 69)])
# modlamp, lda 3 > acc=0.64, est=0.67, cfg=OrderedDict([('shrinkage', 0.9675657964283417), ('solver', 'eigen'), ('tol', 1.5692379869493667e-05)])
# modlamp, gbc 2 > acc=0.71, est=0.70, cfg=OrderedDict([('learning_rate', 0.08895160416425743), ('max_depth', 4), ('max_features', 0.6416120797822377), ('min_samples_leaf', 4), ('min_samples_split', 4), ('n_estimators', 410), ('subsample', 0.6061311836728094)])
# modlamp, mlp 3 > acc=0.66, est=0.68, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.009026464014427856), ('hidden_layer_sizes', 84), ('learning_rate', 'constant'), ('learning_rate_init', 0.00810071967385466), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, catboost 2 > acc=0.71, est=0.70, cfg=OrderedDict([('bagging_temperature', 0.4474239528275963), ('border_count', 133), ('depth', 9), ('iterations', 343), ('l2_leaf_reg', 4.788926090837039), ('learning_rate', 0.026043451730689893), ('random_strength', 2.1895652968697026e-06)])
# modlamp, lightgbm 3 > acc=0.69, est=0.71, cfg=OrderedDict([('colsample_bytree', 0.38453090768690446), ('learning_rate', 0.16467900766362875), ('max_depth', 9), ('min_child_samples', 28), ('min_child_weight', 0.00018721863266560728), ('n_estimators', 28), ('num_leaves', 50), ('reg_alpha', 0.005512267694319562), ('reg_lambda', 0.13150457755909709), ('subsample', 0.6167528732376905)])
# modlamp, lr 4 > acc=0.64, est=0.66, cfg=OrderedDict([('C', 0.3796571844055288), ('fit_intercept', True), ('solver', 'saga')])
# modlamp, xgboost 3 > acc=0.67, est=0.70, cfg=OrderedDict([('colsample_bytree', 0.915199506103644), ('gamma', 0.013449050509130148), ('learning_rate', 0.2332616878767857), ('max_depth', 5), ('min_child_weight', 5), ('n_estimators', 360), ('reg_alpha', 0.686859930187368), ('reg_lambda', 1.7057506246033545), ('scale_pos_weight', 4.923728452903912), ('subsample', 0.7043752238884904)])
# modlamp, knn 4 > acc=0.66, est=0.68, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 17), ('p', 1), ('weights', 'distance')])
# modlamp, nb 4 > acc=0.64, est=0.64, cfg=OrderedDict([('var_smoothing', 0.00014191129358860486)])
# modlamp, rf 2 > acc=0.69, est=0.70, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 21), ('max_features', 0.478892609083704), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 458)])
# modlamp, dt 4 > acc=0.64, est=0.66, cfg=OrderedDict([('criterion', 'entropy'), ('max_depth', 23), ('max_features', 0.8425311980361393), ('min_samples_leaf', 6), ('min_samples_split', 7), ('splitter', 'best')])
# modlamp, svm 4 > acc=0.64, est=0.67, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, ridge 4 > acc=0.65, est=0.66, cfg=OrderedDict([('alpha', 439.73607701862176), ('fit_intercept', False), ('solver', 'saga')])
# modlamp, gpc 4 > acc=0.62, est=0.65, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 4 > acc=0.65, est=0.66, cfg=OrderedDict([('reg_param', 0.4474239528275963), ('store_covariance', True), ('tol', 0.029173699233135845)])
# modlamp, et 3 > acc=0.67, est=0.71, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced'), ('criterion', 'gini'), ('max_depth', 11), ('max_features', 0.5031571727059295), ('min_samples_leaf', 7), ('min_samples_split', 7), ('n_estimators', 183)])
# modlamp, ada 3 > acc=0.67, est=0.66, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.019695923033569554), ('n_estimators', 303)])
# modlamp, lda 4 > acc=0.65, est=0.66, cfg=OrderedDict([('shrinkage', 0.31614545298544944), ('solver', 'lsqr'), ('tol', 4.467549045581762e-05)])
# modlamp, gbc 3 > acc=0.69, est=0.71, cfg=OrderedDict([('learning_rate', 0.42959121911479603), ('max_depth', 6), ('max_features', 0.12322117102129729), ('min_samples_leaf', 6), ('min_samples_split', 6), ('n_estimators', 232), ('subsample', 0.7630836028948478)])
# modlamp, mlp 4 > acc=0.67, est=0.68, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.001186334067387707), ('hidden_layer_sizes', 88), ('learning_rate', 'constant'), ('learning_rate_init', 0.0018322104829247405), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, catboost 3 > acc=0.70, est=0.71, cfg=OrderedDict([('bagging_temperature', 0.7034400418549065), ('border_count', 106), ('depth', 4), ('iterations', 207), ('l2_leaf_reg', 4.755700510543695), ('learning_rate', 0.4169820788205275), ('random_strength', 8.384782344882137)])
# modlamp, xgboost 4 > acc=0.69, est=0.68, cfg=OrderedDict([('colsample_bytree', 0.7237119764137981), ('gamma', 0.518551750501925), ('learning_rate', 0.26121188384235583), ('max_depth', 8), ('min_child_weight', 5), ('n_estimators', 262), ('reg_alpha', 0.3340357901182562), ('reg_lambda', 2.827399586710458), ('scale_pos_weight', 2.332216010898506), ('subsample', 0.6744128576493404)])
# modlamp, lr 5 > acc=0.65, est=0.64, cfg=OrderedDict([('C', 0.0008547165193950983), ('fit_intercept', True), ('solver', 'sag')])
# modlamp, rf 3 > acc=0.70, est=0.70, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'entropy'), ('max_depth', 18), ('max_features', 0.5235619330458103), ('min_samples_leaf', 5), ('min_samples_split', 8), ('n_estimators', 258)])
# modlamp, nb 5 > acc=0.64, est=0.65, cfg=OrderedDict([('var_smoothing', 7.038195949977948e-05)])
# modlamp, knn 5 > acc=0.72, est=0.64, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 17), ('p', 1), ('weights', 'distance')])
# modlamp, lightgbm 4 > acc=0.69, est=0.69, cfg=OrderedDict([('colsample_bytree', 0.5026815575448367), ('learning_rate', 0.03594638748649799), ('max_depth', 9), ('min_child_samples', 34), ('min_child_weight', 6.94998033480578e-05), ('n_estimators', 241), ('num_leaves', 35), ('reg_alpha', 0.9136997933552291), ('reg_lambda', 0.33305400272462654), ('subsample', 0.4139431437688128)])
# modlamp, dt 5 > acc=0.64, est=0.64, cfg=OrderedDict([('criterion', 'gini'), ('max_depth', 3), ('max_features', 0.7928811003072659), ('min_samples_leaf', 4), ('min_samples_split', 6), ('splitter', 'random')])
# modlamp, svm 5 > acc=0.64, est=0.63, cfg=OrderedDict([('C', 2.498809490289807e-05), ('loss', 'squared_hinge'), ('tol', 0.00031838927761288757)])
# modlamp, ridge 5 > acc=0.64, est=0.64, cfg=OrderedDict([('alpha', 1050.705620369744), ('fit_intercept', False), ('solver', 'auto')])
# modlamp, gpc 5 > acc=0.66, est=0.59, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 5 > acc=0.66, est=0.64, cfg=OrderedDict([('reg_param', 0.11647776222456444), ('store_covariance', True), ('tol', 0.0031838927761288754)])
# modlamp, et 4 > acc=0.70, est=0.71, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 21), ('max_features', 0.478892609083704), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 458)])
# modlamp, gbc 4 > acc=0.69, est=0.71, cfg=OrderedDict([('learning_rate', 0.021992361138544005), ('max_depth', 7), ('max_features', 0.8796230877866216), ('min_samples_leaf', 7), ('min_samples_split', 5), ('n_estimators', 241), ('subsample', 0.40063221110643055)])
# modlamp, ada 4 > acc=0.67, est=0.67, cfg=OrderedDict([('algorithm', 'SAMME'), ('learning_rate', 0.16467900766362875), ('n_estimators', 414)])
# modlamp, lda 5 > acc=0.65, est=0.65, cfg=OrderedDict([('shrinkage', 0.31614545298544944), ('solver', 'lsqr'), ('tol', 4.467549045581762e-05)])
# modlamp, mlp 5 > acc=0.68, est=0.65, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.009026464014427856), ('hidden_layer_sizes', 84), ('learning_rate', 'constant'), ('learning_rate_init', 0.00810071967385466), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, xgboost 5 > acc=0.70, est=0.68, cfg=OrderedDict([('colsample_bytree', 0.8513224962221795), ('gamma', 0.061651731814223246), ('learning_rate', 0.11929864409041845), ('max_depth', 4), ('min_child_weight', 5), ('n_estimators', 450), ('reg_alpha', 0.05848718590845105), ('reg_lambda', 1.5113896356547571), ('scale_pos_weight', 2.9158263103973225), ('subsample', 0.8380437488771677)])
# modlamp, catboost 4 > acc=0.70, est=0.71, cfg=OrderedDict([('bagging_temperature', 0.4474239528275963), ('border_count', 133), ('depth', 9), ('iterations', 343), ('l2_leaf_reg', 4.788926090837039), ('learning_rate', 0.026043451730689893), ('random_strength', 2.1895652968697026e-06)])
# modlamp, lightgbm 5 > acc=0.71, est=0.69, cfg=OrderedDict([('colsample_bytree', 0.5026815575448367), ('learning_rate', 0.03594638748649799), ('max_depth', 9), ('min_child_samples', 34), ('min_child_weight', 6.94998033480578e-05), ('n_estimators', 241), ('num_leaves', 35), ('reg_alpha', 0.9136997933552291), ('reg_lambda', 0.33305400272462654), ('subsample', 0.4139431437688128)])
# modlamp, rf 4 > acc=0.70, est=0.71, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'entropy'), ('max_depth', 15), ('max_features', 0.4631078489530096), ('min_samples_leaf', 8), ('min_samples_split', 2), ('n_estimators', 190)])
# modlamp, lr 6 > acc=0.64, est=0.62, cfg=OrderedDict([('C', 41.79842712265741), ('fit_intercept', False), ('solver', 'newton-cg')])
# modlamp, nb 6 > acc=0.67, est=0.62, cfg=OrderedDict([('var_smoothing', 0.00021076812497703017)])
# modlamp, dt 6 > acc=0.63, est=0.63, cfg=OrderedDict([('criterion', 'gini'), ('max_depth', 5), ('max_features', 0.43920268855647115), ('min_samples_leaf', 2), ('min_samples_split', 6), ('splitter', 'random')])
# modlamp, knn 6 > acc=0.73, est=0.66, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 21), ('p', 1), ('weights', 'distance')])
# modlamp, svm 6 > acc=0.68, est=0.62, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, ridge 6 > acc=0.66, est=0.63, cfg=OrderedDict([('alpha', 41.79842712265741), ('fit_intercept', False), ('solver', 'lsqr')])
# modlamp, gpc 6 > acc=0.67, est=0.60, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 6 > acc=0.67, est=0.63, cfg=OrderedDict([('reg_param', 0.11647776222456444), ('store_covariance', True), ('tol', 0.0031838927761288754)])
# modlamp, et 5 > acc=0.72, est=0.68, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 18), ('max_features', 0.6725570810895147), ('min_samples_leaf', 1), ('min_samples_split', 6), ('n_estimators', 13)])
# modlamp, ada 5 > acc=0.65, est=0.66, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.01716797160783964), ('n_estimators', 69)])
# modlamp, lda 6 > acc=0.68, est=0.62, cfg=OrderedDict([('shrinkage', 0.8303990122072878), ('solver', 'eigen'), ('tol', 3.465259624840768e-05)])
# modlamp, gbc 5 > acc=0.73, est=0.71, cfg=OrderedDict([('learning_rate', 0.1289199491569798), ('max_depth', 6), ('max_features', 0.2088265524244978), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 438), ('subsample', 0.9931142614168089)])
# modlamp, mlp 6 > acc=0.69, est=0.64, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.001186334067387707), ('hidden_layer_sizes', 88), ('learning_rate', 'constant'), ('learning_rate_init', 0.0018322104829247405), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, catboost 5 > acc=0.73, est=0.70, cfg=OrderedDict([('bagging_temperature', 0.4474239528275963), ('border_count', 133), ('depth', 9), ('iterations', 343), ('l2_leaf_reg', 4.788926090837039), ('learning_rate', 0.026043451730689893), ('random_strength', 2.1895652968697026e-06)])
# modlamp, lightgbm 6 > acc=0.72, est=0.67, cfg=OrderedDict([('colsample_bytree', 0.7330960376694159), ('learning_rate', 0.01716797160783964), ('max_depth', 4), ('min_child_samples', 21), ('min_child_weight', 6.832822098683475e-05), ('n_estimators', 438), ('num_leaves', 99), ('reg_alpha', 0.6288696575133238), ('reg_lambda', 0.5271565491864922), ('subsample', 0.6829714454791113)])
# modlamp, lr 7 > acc=0.61, est=0.69, cfg=OrderedDict([('C', 0.0008547165193950983), ('fit_intercept', True), ('solver', 'sag')])
# modlamp, xgboost 6 > acc=0.73, est=0.67, cfg=OrderedDict([('colsample_bytree', 0.7237119764137981), ('gamma', 0.518551750501925), ('learning_rate', 0.26121188384235583), ('max_depth', 8), ('min_child_weight', 5), ('n_estimators', 262), ('reg_alpha', 0.3340357901182562), ('reg_lambda', 2.827399586710458), ('scale_pos_weight', 2.332216010898506), ('subsample', 0.6744128576493404)])
# modlamp, rf 5 > acc=0.73, est=0.69, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'entropy'), ('max_depth', 18), ('max_features', 0.5235619330458103), ('min_samples_leaf', 5), ('min_samples_split', 8), ('n_estimators', 258)])
# modlamp, nb 7 > acc=0.62, est=0.68, cfg=OrderedDict([('var_smoothing', 0.00014191129358860486)])
# modlamp, knn 7 > acc=0.65, est=0.71, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 17), ('p', 1), ('weights', 'distance')])
# modlamp, dt 7 > acc=0.63, est=0.67, cfg=OrderedDict([('criterion', 'entropy'), ('max_depth', 23), ('max_features', 0.8425311980361393), ('min_samples_leaf', 6), ('min_samples_split', 7), ('splitter', 'best')])
# modlamp, svm 7 > acc=0.61, est=0.68, cfg=OrderedDict([('C', 2.498809490289807e-05), ('loss', 'squared_hinge'), ('tol', 0.00031838927761288757)])
# modlamp, ridge 7 > acc=0.61, est=0.69, cfg=OrderedDict([('alpha', 5502.07329435664), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, gpc 7 > acc=0.64, est=0.67, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 7 > acc=0.62, est=0.69, cfg=OrderedDict([('reg_param', 0.8776851319206269), ('store_covariance', False), ('tol', 1.2682509740499439e-05)])
# modlamp, et 6 > acc=0.74, est=0.67, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 23), ('max_features', 0.8721933994149386), ('min_samples_leaf', 4), ('min_samples_split', 8), ('n_estimators', 460)])
# modlamp, ada 6 > acc=0.68, est=0.65, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.019695923033569554), ('n_estimators', 303)])
# modlamp, lda 7 > acc=0.61, est=0.69, cfg=OrderedDict([('shrinkage', 0.31614545298544944), ('solver', 'lsqr'), ('tol', 4.467549045581762e-05)])
# modlamp, mlp 7 > acc=0.64, est=0.70, cfg=OrderedDict([('activation', 'logistic'), ('alpha', 0.009026464014427856), ('hidden_layer_sizes', 84), ('learning_rate', 'constant'), ('learning_rate_init', 0.00810071967385466), ('max_iter', 1000), ('solver', 'adam')])
# modlamp, gbc 6 > acc=0.74, est=0.68, cfg=OrderedDict([('learning_rate', 0.1289199491569798), ('max_depth', 6), ('max_features', 0.2088265524244978), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 438), ('subsample', 0.9931142614168089)])
# modlamp, lightgbm 7 > acc=0.68, est=0.71, cfg=OrderedDict([('colsample_bytree', 0.7330960376694159), ('learning_rate', 0.01716797160783964), ('max_depth', 4), ('min_child_samples', 21), ('min_child_weight', 6.832822098683475e-05), ('n_estimators', 438), ('num_leaves', 99), ('reg_alpha', 0.6288696575133238), ('reg_lambda', 0.5271565491864922), ('subsample', 0.6829714454791113)])
# modlamp, catboost 6 > acc=0.74, est=0.68, cfg=OrderedDict([('bagging_temperature', 0.4474239528275963), ('border_count', 133), ('depth', 9), ('iterations', 343), ('l2_leaf_reg', 4.788926090837039), ('learning_rate', 0.026043451730689893), ('random_strength', 2.1895652968697026e-06)])
# modlamp, lr 8 > acc=0.63, est=0.67, cfg=OrderedDict([('C', 0.0008547165193950983), ('fit_intercept', True), ('solver', 'sag')])
# modlamp, rf 6 > acc=0.73, est=0.68, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'entropy'), ('max_depth', 18), ('max_features', 0.5235619330458103), ('min_samples_leaf', 5), ('min_samples_split', 8), ('n_estimators', 258)])
# modlamp, nb 8 > acc=0.63, est=0.66, cfg=OrderedDict([('var_smoothing', 7.003402338794183e-08)])
# modlamp, xgboost 7 > acc=0.68, est=0.69, cfg=OrderedDict([('colsample_bytree', 0.915199506103644), ('gamma', 0.013449050509130148), ('learning_rate', 0.2332616878767857), ('max_depth', 5), ('min_child_weight', 5), ('n_estimators', 360), ('reg_alpha', 0.686859930187368), ('reg_lambda', 1.7057506246033545), ('scale_pos_weight', 4.923728452903912), ('subsample', 0.7043752238884904)])
# modlamp, knn 8 > acc=0.66, est=0.69, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 21), ('p', 1), ('weights', 'distance')])
# modlamp, dt 8 > acc=0.64, est=0.65, cfg=OrderedDict([('criterion', 'entropy'), ('max_depth', 17), ('max_features', 0.8796230877866216), ('min_samples_leaf', 7), ('min_samples_split', 5), ('splitter', 'best')])
# modlamp, svm 8 > acc=0.63, est=0.66, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, ridge 8 > acc=0.63, est=0.67, cfg=OrderedDict([('alpha', 5502.07329435664), ('fit_intercept', False), ('solver', 'sag')])
# modlamp, gpc 8 > acc=0.66, est=0.62, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 8 > acc=0.62, est=0.68, cfg=OrderedDict([('reg_param', 0.9675657964283417), ('store_covariance', False), ('tol', 0.002462507859684898)])
# modlamp, et 7 > acc=0.69, est=0.72, cfg=OrderedDict([('bootstrap', False), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 23), ('max_features', 0.8721933994149386), ('min_samples_leaf', 4), ('min_samples_split', 8), ('n_estimators', 460)])
# modlamp, ada 7 > acc=0.64, est=0.67, cfg=OrderedDict([('algorithm', 'SAMME.R'), ('learning_rate', 0.019695923033569554), ('n_estimators', 303)])
# modlamp, lda 8 > acc=0.62, est=0.68, cfg=OrderedDict([('shrinkage', 0.4474239528275963), ('solver', 'lsqr'), ('tol', 5.401268298569866e-05)])
# modlamp, mlp 8 > acc=0.62, est=0.69, cfg=OrderedDict([('activation', 'relu'), ('alpha', 1.1318690952651239e-05), ('hidden_layer_sizes', 79), ('learning_rate', 'constant'), ('learning_rate_init', 0.002207279055460658), ('max_iter', 1001), ('solver', 'sgd')])
# modlamp, gbc 7 > acc=0.72, est=0.73, cfg=OrderedDict([('learning_rate', 0.1289199491569798), ('max_depth', 6), ('max_features', 0.2088265524244978), ('min_samples_leaf', 5), ('min_samples_split', 5), ('n_estimators', 438), ('subsample', 0.9931142614168089)])
# modlamp, catboost 7 > acc=0.67, est=0.74, cfg=OrderedDict([('bagging_temperature', 0.8303990122072878), ('border_count', 4), ('depth', 8), ('iterations', 147), ('l2_leaf_reg', 5.031571727059295), ('learning_rate', 0.11730133055282148), ('random_strength', 0.007389231992179819)])
# modlamp, rf 7 > acc=0.67, est=0.72, cfg=OrderedDict([('bootstrap', True), ('class_weight', 'balanced_subsample'), ('criterion', 'gini'), ('max_depth', 8), ('max_features', 0.6647325698298886), ('min_samples_leaf', 1), ('min_samples_split', 7), ('n_estimators', 160)])
# modlamp, xgboost 8 > acc=0.65, est=0.70, cfg=OrderedDict([('colsample_bytree', 0.8517200209274532), ('gamma', 0.4115729954640338), ('learning_rate', 0.04506633355900484), ('max_depth', 6), ('min_child_weight', 5), ('n_estimators', 443), ('reg_alpha', 0.99234917935201), ('reg_lambda', 2.2577393150266474), ('scale_pos_weight', 3.108626196745969), ('subsample', 0.823873025266173)])
# modlamp, lr 9 > acc=0.66, est=0.63, cfg=OrderedDict([('C', 0.3796571844055288), ('fit_intercept', True), ('solver', 'saga')])
# modlamp, nb 9 > acc=0.65, est=0.61, cfg=OrderedDict([('var_smoothing', 0.05106133530537277)])
# modlamp, knn 9 > acc=0.69, est=0.63, cfg=OrderedDict([('algorithm', 'brute'), ('n_neighbors', 21), ('p', 1), ('weights', 'distance')])
# modlamp, dt 9 > acc=0.66, est=0.62, cfg=OrderedDict([('criterion', 'entropy'), ('max_depth', 17), ('max_features', 0.8796230877866216), ('min_samples_leaf', 7), ('min_samples_split', 5), ('splitter', 'best')])
# modlamp, lightgbm 8 > acc=0.65, est=0.70, cfg=OrderedDict([('colsample_bytree', 0.7330960376694159), ('learning_rate', 0.01716797160783964), ('max_depth', 4), ('min_child_samples', 21), ('min_child_weight', 6.832822098683475e-05), ('n_estimators', 438), ('num_leaves', 99), ('reg_alpha', 0.6288696575133238), ('reg_lambda', 0.5271565491864922), ('subsample', 0.6829714454791113)])
# modlamp, svm 9 > acc=0.66, est=0.63, cfg=OrderedDict([('C', 0.006219356272098938), ('loss', 'squared_hinge'), ('tol', 0.0019958994474678477)])
# modlamp, ridge 9 > acc=0.66, est=0.63, cfg=OrderedDict([('alpha', 439.73607701862176), ('fit_intercept', False), ('solver', 'saga')])
# modlamp, gpc 9 > acc=0.65, est=0.61, cfg=OrderedDict([('max_iter_predict', 732), ('n_restarts_optimizer', 1), ('optimizer', 'fmin_l_bfgs_b')])
# modlamp, qda 9 > acc=0.67, est=0.63, cfg=OrderedDict([('reg_param', 0.702644992444359), ('store_covariance', False), ('tol', 0.0003217862663291412)])
